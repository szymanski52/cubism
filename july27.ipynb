# %% [markdown]
# <a href="https://colab.research.google.com/github/szymanski52/cubism/blob/main/july27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dataset

# %%
from torchvision import transforms, datasets
import os
import zipfile
import torch.nn as nn
import gdown
from matplotlib import pyplot as plt
from torch.utils.data import Dataset
from natsort import natsorted
from PIL import Image
from google.colab import files
import cv2 as cv
import numpy as np
import torch

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#files.upload()
# !unzip drive/MyDrive/fashion.zip -d fashion
# !rm -r fashion/__MACOSX
#!unzip gpics.zip -d gpics
#!rm -r gpics/__MACOSX
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: fashion/fashion1024/dbc9741224d96ce55e8d7271ab503a13.jpg
#   inflating: fashion/__MACOSX/fashion1024/._dbc9741224d96ce55e8d7271ab503a13.jpg
#   inflating: fashion/fashion1024/439b392325222507b26f6cab94503396.jpg
#   inflating: fashion/__MACOSX/fashion1024/._439b392325222507b26f6cab94503396.jpg
#   inflating: fashion/fashion1024/f8455874bcd0ab0d20d73c6de789e649.jpg
#   inflating: fashion/__MACOSX/fashion1024/._f8455874bcd0ab0d20d73c6de789e649.jpg
#   inflating: fashion/fashion1024/ff526d49db684c552bad724a55254fb8.jpg
#   inflating: fashion/__MACOSX/fashion1024/._ff526d49db684c552bad724a55254fb8.jpg
#   inflating: fashion/fashion1024/2cf45136963ef9ef6d9794d7914eb373.jpg
#   inflating: fashion/__MACOSX/fashion1024/._2cf45136963ef9ef6d9794d7914eb373.jpg
#   inflating: fashion/fashion1024/3e260bd5baaaa58327e441286d60a8f9.jpg
#   inflating: fashion/__MACOSX/fashion1024/._3e260bd5baaaa58327e441286d60a8f9.jpg
#   inflating: fashion/fashion1024/7ac0279f69a6a0c85f57161f7fcbbedc.jpg
#   inflating: fashion/__MACOSX/fashion1024/._7ac0279f69a6a0c85f57161f7fcbbedc.jpg
#   inflating: fashion/fashion1024/bcdbcc82dd77f448d723a7a6cc5e17fd.jpg
#   inflating: fashion/__MACOSX/fashion1024/._bcdbcc82dd77f448d723a7a6cc5e17fd.jpg
#   inflating: fashion/fashion1024/af776e656783eda9d594344b5ed24eab.jpg
#   inflating: fashion/__MACOSX/fashion1024/._af776e656783eda9d594344b5ed24eab.jpg
#   inflating: fashion/fashion1024/4596403d3fcfb2896e30a1e9565454ae.jpg
#   inflating: fashion/__MACOSX/fashion1024/._4596403d3fcfb2896e30a1e9565454ae.jpg
#   inflating: fashion/fashion1024/066ec8e6f0e67f839bd009c5e3947ff5.jpg
#   inflating: fashion/__MACOSX/fashion1024/._066ec8e6f0e67f839bd009c5e3947ff5.jpg
#   inflating: fashion/fashion1024/caa8e6f1926970c2740dbbd1b62b8147.jpg
#   inflating: fashion/__MACOSX/fashion1024/._caa8e6f1926970c2740dbbd1b62b8147.jpg
#   inflating: fashion/fashion1024/7c41c85ee9524f8f34df13f84e837705.jpg
#   inflating: fashion/__MACOSX/fashion1024/._7c41c85ee9524f8f34df13f84e837705.jpg
#   inflating: fashion/fashion1024/b0323e8b0ec48528cb21e9bd8c0262b6.jpg
#   inflating: fashion/__MACOSX/fashion1024/._b0323e8b0ec48528cb21e9bd8c0262b6.jpg
#   inflating: fashion/fashion1024/bc9fb1185c361e012a63a39436fa8637.jpg
#   inflating: fashion/__MACOSX/fashion1024/._bc9fb1185c361e012a63a39436fa8637.jpg
#   inflating: fashion/fashion1024/94d03eaeb838708b29b2054a35092160.jpg
#   inflating: fashion/__MACOSX/fashion1024/._94d03eaeb838708b29b2054a35092160.jpg
#   inflating: fashion/fashion1024/99b941dfc04c67e25bdc32be1bfc35a6.jpg
#   inflating: fashion/__MACOSX/fashion1024/
#   inflating: fashion/__MACOSX/fashion1024/._c1b67f7a568c4b1035f0684f70a84354.jpg
#   inflating: fashion/fashion1024/b2193271ffae19b0dcaf9db6a896a93a.jpg
#   inflating: fashion/__MACOSX/fashion1024/._b2193271ffae19b0dcaf9db6a896a93a.jpg
#   inflating: fashion/fashion1024/3a32ece87e750c3b348bbcacc303276e.jpg
#   inflating: fashion/__MACOSX/fashion1024/._3a32ece87e750c3b348bbcacc303276e.jpg
#   inflating: fashion/fashion1024/bfdf5a7cbfe3f47a9123a5937724da00.jpg
#   inflating: fashion/__MACOSX/fashion1024/._bfdf5a7cbfe3f47a9123a5937724da00.jpg
#   inflating: fashion/fashion1024/2a868b86eb6f7cbae6c0816487260d00.jpg
#   inflating: fashion/__MACOSX/fashion1024/._2a868b86eb6f7cbae6c0816487260d00.jpg
#   inflating: fashion/fashion1024/4789aab7dffdf2ebe4ea809275df5e26.jpg
#   inflating: fashion/__MACOSX/fashion1024/._4789aab7dffdf2ebe4ea809275df5e26.jpg
#   inflating: fashion/fashion1024/f9ff2fac59cc9cdbbec95f1f9378d727.jpg
#   inflating: fashion/__MACOSX/fashion1024/._f9ff2fac59cc9cdbbec95f1f9378d727.jpg

# %%
class CannyDataset(Dataset):
  def __init__(self, root_dir, transform=None):
    image_names = os.listdir(root_dir)
    self.def_img = '01361d9b8bfdcc0c6801df23d60bc692.jpg'
    self.root_dir = root_dir
    self.transform = transform 
    self.image_names = natsorted(image_names)

  def __len__(self): 
    return len(self.image_names)

  def __getitem__(self, idx):
    try:
        img_path = os.path.join(self.root_dir, self.image_names[idx])
        img = cv.imread(img_path)
        img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    except:
        img_path = os.path.join(self.root_dir, self.def_img)
        img = cv.imread(img_path)
        img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    canny = cv.Canny(img, 250, 300)
    canny = cv.cvtColor(canny, cv.COLOR_BGR2RGB)
    if self.transform:
        img = self.transform(Image.fromarray(img))
        canny = self.transform(Image.fromarray(canny))
    return img, canny

# %%
ngpu = 1
device = torch.device('cuda:0' if (
    torch.cuda.is_available() and ngpu > 0) else 'cpu')
# Spatial size of training images, images are resized to this size.
image_size = 256
# Transformations to be applied to each individual image sample
transform=transforms.Compose([
    transforms.Resize(image_size),
    #transforms.CenterCrop(image_size),
    transforms.ToTensor(),
    #transforms.Normalize(mean=[0.5, 0.5, 0.5],
    #                      std=[0.5, 0.5, 0.5])
])
# Load the dataset from file and apply transformations
canny_dataset = CannyDataset(f'fashion/fashion1024', transform)

# Batch size during training
batch_size = 32
# Number of workers for the dataloader
num_workers = 0 if device.type == 'cuda' else 2
# Whether to put fetched data tensors to pinned memory
pin_memory = True if device.type == 'cuda' else False

canny_dataloader = torch.utils.data.DataLoader(canny_dataset,
                                               batch_size=batch_size,
                                               num_workers=num_workers,
                                               pin_memory=pin_memory,
                                               shuffle=True,
                                               drop_last=True
                                              )

# %%
item = canny_dataset.__getitem__(30000)
im = item[0]
target = item[1]

# %%
transforms.ToPILImage()(im)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F28F39B1350>

# %%
transforms.ToPILImage()(target*255)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F28F3A58050>

# %% [markdown]
# #Model

# %%
def draw_line(c, out_size = 256):
    e = torch.Tensor([[i for i in range(1,out_size+1)]]).to(device)
    e = e.repeat(out_size,1)
    e_x = e
    e_y = e.T
    if (c[1][1] - c[0][1]) * (c[1][0] - c[0][0]):
        kf = abs((c[1][1] - c[0][1]) / (c[1][0] - c[0][0]))
        if kf <= 1:
            if(c[1][0] < c[0][0]) and (c[1][1] < c[0][1]):
                d = 1 - torch.abs(e_y - (c[0][1] - c[1][1]) * (e_x - c[1][0]) / (c[0][0] - c[1][0]) - c[1][1])
                b1 = e_x - c[1][0] + 1
                b1 = torch.clamp(b1, 0, 1)
                b2 = c[0][0] - e_x + 1
                b2 = torch.clamp(b2, 0, 1)
            else:
                d = 1 - torch.abs(e_y - (c[1][1] - c[0][1]) * (e_x - c[0][0]) / (c[1][0] - c[0][0]) - c[0][1])
                b1 = e_x - c[0][0] + 1
                b1 = torch.clamp(b1, 0, 1)
                b2 = c[1][0] - e_x + 1
                b2 = torch.clamp(b2, 0, 1)
        else:
            if(c[1][0] < c[0][0]) and (c[1][1] < c[0][1]):
                d = 1 - torch.abs(e_x - (c[0][0] - c[1][0]) * (e_y - c[1][1]) / (c[0][1] - c[1][1]) - c[1][0])
                b1 = e_y - c[1][1] + 1
                b1 = torch.clamp(b1, 0, 1)
                b2 = c[0][1] - e_y + 1
                b2 = torch.clamp(b2, 0, 1)
            else:
                d = 1 - torch.abs(e_x - (c[1][0] - c[0][0]) * (e_y - c[0][1]) / (c[1][1] - c[0][1]) - c[0][0])
                b1 = e_y - c[0][1] + 1
                b1 = torch.clamp(b1, 0, 1)
                b2 = c[1][1] - e_y + 1
                b2 = torch.clamp(b2, 0, 1)
    elif not (c[1][0] - c[0][0]):
        d = 1 - torch.abs(e_x - c[0][0])
        b1 = e_y - c[1][1] + 1
        b1 = torch.clamp(b1, 0, 1)
        b2 = c[0][1] - e_y + 1
        b2 = torch.clamp(b2, 0, 1)
    else:
        d = 1 - torch.abs(e_y - c[1][1])
        b1 = e_x - c[0][0] + 1
        b1 = torch.clamp(b1, 0, 1)
        b2 = c[1][0] - e_x + 1
        b2 = torch.clamp(b2, 0, 1)
    if ((c[0][0] - c[1][0]) ** 2 + (c[0][1] - c[1][1]) ** 2) ** 0.5 <= 30:
        b1 += torch.ones((256, 256)).to(device)
        b2 += torch.ones((256, 256)).to(device)
    k = d * (d > 0)    
    f = k * b1 * b2
    return f

# %%
from torch.nn import Module
from typing import Tuple, Union
from torch import Tensor
from torch.types import _size


class Render(Module):
    __constants__ = ['out_size', 'line_w']
    out_size: int
    line_w: int

    def __init__(self, out_size: int = 256, line_w: int = 10) -> None:
        super(Render, self).__init__()
        self.out_size = out_size
        self.line_w = line_w

    def forward(self, input: Tensor) -> Tensor:
        points = input.reshape(input.shape[0],20,2,2) * self.out_size
        silhouettes = torch.Tensor().to(device)
        for k in points:
            silhouette = torch.zeros((3, self.out_size, self.out_size)).to(device)
            for l in k:
                s = draw_line(l)
                silhouette[0] += s
                silhouette[1] += s
                silhouette[2] += s
            silhouettes = torch.cat((silhouettes, silhouette))
        silhouettes = silhouettes.resize(input.shape[0], 3,
                                         self.out_size,
                                         self.out_size)  
        return silhouettes

# %%
class LinesGenerator(nn.Module):
    def __init__(self, lines_n):
        self.points = None
        super(LinesGenerator, self).__init__()
        self.conv1 = nn.Conv2d(3, 3, 57)
        self.bn1 = nn.BatchNorm2d(3),
        self.relu1 = nn.LeakyReLU(0.2, inplace=True)
        self.conv2 = nn.Conv2d(3, 3, 73)
        self.bn2 = nn.BatchNorm2d(3),
        self.relu2 = nn.LeakyReLU(0.2, inplace=True)
        self.dropout1 = nn.Dropout(0.5)
        self.conv3 = nn.Conv2d(3, 3, 29)
        #self.conv3 = nn.Conv2d(3, 3, 65)
        self.bn3 = nn.BatchNorm2d(3),
        self.relu3 = nn.LeakyReLU(0.2, inplace=True)
        self.conv4 = nn.Conv2d(3, 3, 33)
        self.bn4 = nn.BatchNorm2d(3),
        self.relu4 = nn.LeakyReLU(0.2, inplace=True)
        self.dropout2 = nn.Dropout(0.5)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(30000,10240)
        #self.fc1 = nn.Linear(3072,1024)
        self.tanh1 = nn.Tanh()
        self.fc2 = nn.Linear(10240,2512)
        self.relu5 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.3)
        self.fc3 = nn.Linear(2512, 256)
        self.tanh2 = nn.Tanh()
        self.fc4 = nn.Linear(256, lines_n * 4)
        self.sigmoid = nn.Sigmoid()
        self.render = Render()

    def forward(self, X):
        x = self.conv1(X)
        x = self.relu1(x)
        x = self.conv2(x)
        x = self.relu2(x)
        x = self.dropout1(x)
        x = self.conv3(x)
        x = self.relu3(x)
        #x = self.conv4(x)
        #x = self.relu4(x)
        x = self.dropout2(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.tanh1(x)
        x = self.fc2(x)
        x = self.relu5(x)
        x = self.dropout3(x)
        x = self.fc3(x)
        x = self.tanh2(x)
        x = self.fc4(x)
        x = self.sigmoid(x)
        self.points = x * 255
        x = self.render(x)
        return x

# %%
class LinesGenerator(nn.Module):
    def __init__(self, lines_n):
        self.points = None
        super(LinesGenerator, self).__init__()
        self.conv1 = nn.Conv2d(3, 3, 65)
        self.bn1 = nn.BatchNorm2d(3),
        self.relu1 = nn.LeakyReLU(0.2, inplace=True)
        self.conv2 = nn.Conv2d(3, 3, 65)
        self.bn2 = nn.BatchNorm2d(3),
        self.relu2 = nn.LeakyReLU(0.2, inplace=True)
        self.dropout1 = nn.Dropout(0.5)
        self.conv3 = nn.Conv2d(3, 3, 65)
        self.bn3 = nn.BatchNorm2d(3),
        self.relu3 = nn.LeakyReLU(0.2, inplace=True)
        self.conv4 = nn.Conv2d(3, 3, 79)
        self.bn4 = nn.BatchNorm2d(3),
        self.relu4 = nn.LeakyReLU(0.2, inplace=True)
        self.dropout2 = nn.Dropout(0.5)
        
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(7500, 7000)
        self.relu6 = nn.LeakyReLU(0.2, inplace=True)
        self.fc2 = nn.Linear(7000, 6000)
        self.relu7 = nn.LeakyReLU(0.2, inplace=True)
        self.dropout3 = nn.Dropout(0.3)
        self.fc3 = nn.Linear(6000, 5000)
        self.relu8 = nn.LeakyReLU(0.2, inplace=True)
        self.fc4 = nn.Linear(5000, 4000)
        self.relu9 = nn.LeakyReLU(0.2, inplace=True)
        self.dropout4 = nn.Dropout(0.3)
        self.fc5 = nn.Linear(4000,3000)
        self.relu10 = nn.LeakyReLU(0.2, inplace=True)
        self.fc6 = nn.Linear(3000,2000)
        self.relu11 = nn.LeakyReLU(0.2, inplace=True)
        self.dropout5 = nn.Dropout(0.3)
        self.fc7 = nn.Linear(2000,1000)
        self.relu12 = nn.LeakyReLU(0.2, inplace=True)
        self.fc8 = nn.Linear(1000,500)
        self.relu13 = nn.LeakyReLU(0.2, inplace=True)
        self.dropout6 = nn.Dropout(0.3)
        self.fc9 = nn.Linear(500,400)
        self.relu14 = nn.LeakyReLU(0.2, inplace=True)
        self.fc10 = nn.Linear(400,200)
        self.relu15 = nn.LeakyReLU(0.2, inplace=True)
        self.dropout7 = nn.Dropout(0.3)
        self.fc11 = nn.Linear(200, lines_n * 4)
        self.relu16 = nn.LeakyReLU(0.2, inplace=True)
        self.sigmoid = nn.Sigmoid()
        self.render = Render()

    def forward(self, X):
        x = self.conv1(X)
        x = self.relu1(x)
        #x = self.conv2(x)
        #x = self.relu2(x)
        x = self.dropout1(x)
        x = self.conv3(x)
        x = self.relu3(x)
        x = self.conv4(x)
        x = self.relu4(x)
        x = self.dropout2(x)
        x = self.flatten(x)

        x = self.fc1(x)
        x = self.relu6(x)
        x = self.fc2(x)
        x = self.relu7(x)
        x = self.dropout3(x)

        x = self.fc3(x)
        x = self.relu8(x)
        x = self.fc4(x)
        x = self.relu9(x)
        x = self.dropout4(x)

        x = self.fc5(x)
        x = self.relu10(x)
        x = self.fc6(x)
        x = self.relu11(x)
        x = self.dropout5(x)

        x = self.fc7(x)
        x = self.relu12(x)
        x = self.fc8(x)
        x = self.relu13(x)
        x = self.dropout6(x)

        x = self.fc9(x)
        x = self.relu14(x)
        x = self.fc10(x)
        x = self.relu15(x)
        x = self.dropout7(x)

        x = self.fc11(x)
        x = self.relu16(x)
        x = self.sigmoid(x)
        self.points = x * 255
        x = self.render(x)
        return x

# %%
model = LinesGenerator(20)
model.cuda()
# Out:
# LinesGenerator(
#   (conv1): Conv2d(3, 3, kernel_size=(65, 65), stride=(1, 1))
#   (relu1): LeakyReLU(negative_slope=0.2, inplace=True)
#   (conv2): Conv2d(3, 3, kernel_size=(65, 65), stride=(1, 1))
#   (relu2): LeakyReLU(negative_slope=0.2, inplace=True)
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (conv3): Conv2d(3, 3, kernel_size=(65, 65), stride=(1, 1))
#   (relu3): LeakyReLU(negative_slope=0.2, inplace=True)
#   (conv4): Conv2d(3, 3, kernel_size=(79, 79), stride=(1, 1))
#   (relu4): LeakyReLU(negative_slope=0.2, inplace=True)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=7500, out_features=7000, bias=True)
#   (relu6): LeakyReLU(negative_slope=0.2, inplace=True)
#   (fc2): Linear(in_features=7000, out_features=6000, bias=True)
#   (relu7): LeakyReLU(negative_slope=0.2, inplace=True)
#   (dropout3): Dropout(p=0.3, inplace=False)
#   (fc3): Linear(in_features=6000, out_features=5000, bias=True)
#   (relu8): LeakyReLU(negative_slope=0.2, inplace=True)
#   (fc4): Linear(in_features=5000, out_features=4000, bias=True)
#   (relu9): LeakyReLU(negative_slope=0.2, inplace=True)
#   (dropout4): Dropout(p=0.3, inplace=False)
#   (fc5): Linear(in_features=4000, out_features=3000, bias=True)
#   (relu10): LeakyReLU(negative_slope=0.2, inplace=True)
#   (fc6): Linear(in_features=3000, out_features=2000, bias=True)
#   (relu11): LeakyReLU(negative_slope=0.2, inplace=True)
#   (dropout5): Dropout(p=0.3, inplace=False)
#   (fc7): Linear(in_features=2000, out_features=1000, bias=True)
#   (relu12): LeakyReLU(negative_slope=0.2, inplace=True)
#   (fc8): Linear(in_features=1000, out_features=500, bias=True)
#   (relu13): LeakyReLU(negative_slope=0.2, inplace=True)
#   (dropout6): Dropout(p=0.3, inplace=False)
#   (fc9): Linear(in_features=500, out_features=400, bias=True)
#   (relu14): LeakyReLU(negative_slope=0.2, inplace=True)
#   (fc10): Linear(in_features=400, out_features=200, bias=True)
#   (relu15): LeakyReLU(negative_slope=0.2, inplace=True)
#   (dropout7): Dropout(p=0.3, inplace=False)
#   (fc11): Linear(in_features=200, out_features=80, bias=True)
#   (relu16): LeakyReLU(negative_slope=0.2, inplace=True)
#   (sigmoid): Sigmoid()
#   (render): Render()
# )

# %% [markdown]
# #Training

# %%
# !pip3 install transformers
from transformers import AdamW
# Out:
# Collecting transformers
#   Downloading transformers-4.9.1-py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 34.7 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.6.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 52.3 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 52.3 MB/s
# Collecting huggingface-hub==0.0.12
#   Downloading huggingface_hub-0.0.12-py3-none-any.whl (37 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 15.3 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (21.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub==0.0.12->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Installing collected packages: tokenizers, sacremoses, pyyaml, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.0.12 pyyaml-5.4.1 sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.9.1

# %%
from sklearn.metrics import f1_score
losses = []
def train(data):
    train_loss = 0
    train_acc = 0
    for i, (img_batch, target_batch) in enumerate(data):
        img_batch = img_batch.to(device)
        output = model(img_batch)
        optimizer.zero_grad()
        target = target_batch.to(device)
        loss = criterion(output, target*5)
        losses.append(loss.item())
        train_loss += loss.item()
        loss.backward()
        optimizer.step()
        scheduler.step()
    return train_loss / len(data)

# %%
import time
from torch.utils.data.dataset import random_split

EPOCHS = 5
LR = 1e-4  # learning rate
  
criterion = nn.MSELoss()
optimizer = AdamW(model.parameters(), lr=LR, eps=1e-8)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1e-2, gamma=1e-6)
device = torch.device('cuda:0')
 
for epoch in range(1, EPOCHS + 1):
    epoch_start_time = time.time()
    loss = train(canny_dataloader)
    print('-' * 90)
    print(loss)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:490: UserWarning: non-inplace resize is deprecated
#   warnings.warn("non-inplace resize is deprecated")
# ------------------------------------------------------------------------------------------
# 0.2877117446425772
# ------------------------------------------------------------------------------------------
# 0.3589150040598101
# ------------------------------------------------------------------------------------------
# 0.3409384721390862

# %% [markdown]
# #Results

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))
plt.title("Generator Loss During Training")
plt.plot(losses)
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# #Evaluation

# %%
def check_by_index(model, index):
    item = canny_dataset.__getitem__(index)
    im = item[0]
    target = item[1]
    out = model(im.to(device).unsqueeze(0))
    img = transforms.ToPILImage()(out[0])
    loss = criterion(out[0], (target).to(device))
    print(criterion._get_name(), loss)
    return img, transforms.ToPILImage()(out[0]+target.to(device)), out

# %%
res = check_by_index(model, 25)

# %%
res[0]

# %%
res[1]
